# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_excel(r'C:\Users\WAKU\Documents\ANTONIO_BOZA\DATA_WAKU\EXPRESS\PLANILLAS VIGENTES DE SM 2019-2020_REV_18-02.xlsx')
df2 = pd.read_excel(r'C:\Users\WAKU\Documents\ANTONIO_BOZA\DATA_WAKU\EXPRESS\Maracaibo_Z_Rev_18-02.xlsx')

# %%
df1.head()
# Out:
#                                       CONTRIBUYENTE        RIF      TELEFONO  \
# 0  CENTRO DE DIAG C Y RADIOL JESUS DE NAZARENO C.A.  312967358  2.610000e+02
# 1                                 CLINICA SUCRE C.A   70133082  2.610000e+02
# 2                    CENTRO MEDICO DE OCCIDENTE C A   70003359  2.617960e+09
# 3                       BIONALISTAS ASOCIADAS, C.A.  301805429  4.140000e+02
# 4                                        MEDLAB C.A  311725415  1.000000e+00
#
#           RIM   AÑO                        CONCEPTO  FECHA LIQ FECHA VENC  \
# 0  2900011642  2020  Pago por Servicios Municipales 2020-02-07 2020-02-29
# 1  2000072525  2020  Pago por Servicios Municipales 2020-02-10 2020-02-29
# 2  2000082649  2020  Pago por Servicios Municipales 2020-02-10 2020-02-29
# 3  7000001567  2020  Pago por Servicios Municipales 2020-02-06 2020-02-29
# 4  2900000607  2020  Pago por Servicios Municipales 2020-02-06 2020-02-29
#
#    SOLICITUD         MONTO  ESTATUS  \
# ...

# %%
df2.head()
# Out:
#    RNUM TIPO CONTRIB        RIF  \
# 0    25            C  295867549
# 1    29            C  295990626
# 2    31            C  296063680
# 3    39            C  296223190
# 4    48            C  296496480
#
#                                         RAZON_SOCIAL  \
# 0                    INVERSIONES LOPEZ & TETE, C.A,
# 1        COOPERATIVA BANCO COMUNAL LA PIONERA,R.L.,
# 2                            PROTECCION TIUNA.C,A,,
# 3  COOPERATIVA  BANCO  COMUNAL INDIGENA NUCHONYUU...
# 4  ASOCIACION COOP BANCO COMUNAL COUTAJIRRAJENA W...
#
#                                    CORREO ACTIVIDAD_ECONOMICA  \
# 0             ALBERTOTETEDIAZ@HOTMAIL.COM                 NaN
# 1         MARINA.RODRIGUEZ.63@HOTMAIL.COM                 NaN
# 2                 LILLYRANGEL@HOTMAIL.COM                 NaN
# 3                        CCJUYA@GMAIL.COM                 NaN
# 4  CCICOUTAJIRRAENAWAYAAWANEPIA@GMAIL.COM                 NaN
#
# ...

# %%
df1_no_duplic = df1.drop_duplicates(subset = "RIF", keep = "first")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3673 entries, 0 to 3672
# Data columns (total 13 columns):
# CONTRIBUYENTE    3672 non-null object
# RIF              3673 non-null int64
# TELEFONO         3671 non-null float64
# RIM              3660 non-null object
# AÑO              3673 non-null int64
# CONCEPTO         3673 non-null object
# FECHA LIQ        3673 non-null datetime64[ns]
# FECHA VENC       3673 non-null datetime64[ns]
# SOLICITUD        3673 non-null int64
# MONTO            3673 non-null float64
# ESTATUS          3673 non-null object
# PARROQUIA        3673 non-null object
# DIRECCION-1      3671 non-null object
# dtypes: datetime64[ns](2), float64(2), int64(3), object(6)
# memory usage: 373.2+ KB

# %%
df1_no_duplic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3230 entries, 0 to 3672
# Data columns (total 13 columns):
# CONTRIBUYENTE    3229 non-null object
# RIF              3230 non-null int64
# TELEFONO         3229 non-null float64
# RIM              3219 non-null object
# AÑO              3230 non-null int64
# CONCEPTO         3230 non-null object
# FECHA LIQ        3230 non-null datetime64[ns]
# FECHA VENC       3230 non-null datetime64[ns]
# SOLICITUD        3230 non-null int64
# MONTO            3230 non-null float64
# ESTATUS          3230 non-null object
# PARROQUIA        3230 non-null object
# DIRECCION-1      3229 non-null object
# dtypes: datetime64[ns](2), float64(2), int64(3), object(6)
# memory usage: 353.3+ KB

# %%
df1_nd_df2 = pd.merge(left = df1_no_duplic, right = df2, on = None, left_on = 'RIF', right_on = 'RIF')

# %%
df1_nd_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3311 entries, 0 to 3310
# Data columns (total 23 columns):
# CONTRIBUYENTE          3310 non-null object
# RIF                    3311 non-null int64
# TELEFONO               3310 non-null float64
# RIM                    3302 non-null object
# AÑO                    3311 non-null int64
# CONCEPTO               3311 non-null object
# FECHA LIQ              3311 non-null datetime64[ns]
# FECHA VENC             3311 non-null datetime64[ns]
# SOLICITUD              3311 non-null int64
# MONTO                  3311 non-null float64
# ESTATUS                3311 non-null object
# PARROQUIA              3311 non-null object
# DIRECCION-1            3310 non-null object
# RNUM                   3311 non-null int64
# TIPO CONTRIB           3311 non-null object
# RAZON_SOCIAL           3311 non-null object
# CORREO                 3311 non-null object
# ACTIVIDAD_ECONOMICA    3265 non-null object
# ...

# %%
archivo_final = df1_nd_df2.to_excel('Consolidado_Planillas_Vs_Seniat_19-02.xlsx')
